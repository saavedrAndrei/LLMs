# %% [markdown]
# # Web Scrapper + LLMs

# %%
# imports
import os
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %% [markdown]
# - API Key

# %%
# Load environment variables in a file called .env

api_key = os.getenv('OPENAI_API_KEY')

# Check the key

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %% [markdown]
# - Message

# %%
# To give you a preview -- calling OpenAI with these messages is this easy. Any problems, head over to the Troubleshooting notebook.

message = "Hello, Llama! My name is Andrei - This project is created for Palantir"

messages = [{"role": "user", "content": message}]

messages
# Out:
# [{'role': 'user',
#   'content': 'Hello, Llama! My name is Andrei - This project is created for Palantir'}]

# %% [markdown]
# - Model Interaction

# %%
openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

# %%
response = openai.chat.completions.create(model="gemma3", messages=messages)
response.choices[0].message.content
# Out:
# "Hello Andrei! It’s fantastic to connect with you! \n\nThat's really interesting – Palantir! That’s a huge name in data integration and analysis, and a very complex undertaking. \n\nI'm excited to hear you're working on a project for them. To help me understand how I can be most helpful to you, could you tell me a little more about the project? For example:\n\n*   **What is the project's overall goal?** (What problem are you trying to solve?)\n*   **What kind of work are you doing?** (Are you building software, analyzing data, documenting requirements, etc.?)\n*   **What specifically do you need help with?** (Do you want brainstorming support, code assistance, research, explanations about Palantir, or something else?)\n\n\nI'm here to listen, share information, and perhaps even offer some support. Let’s see how we can collaborate!"

# %% [markdown]
# ## Web scrapping

# %%
ed = fetch_website_contents("https://edwarddonner.com")
print(ed)

# %% [markdown]
# ## Prompt Engineering

# %%
# Define our system prompt - you can experiment with this later, changing the last sentence to 'Respond in markdown in Spanish."

system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
# Define our user prompt

user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %% [markdown]
# ## Messages Sending

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_prefix + website}
    ]

# %%
messages_for(ed)

# %% [markdown]
# ## Time to bring it together - the API for OpenAI is very simple!

# %%
def summarize(url):
    website = fetch_website_contents(url)
    response = openai.chat.completions.create(
        model = "gpt-4.1-mini",
        messages = messages_for(website)
    )
    return response.choices[0].message.content

# %%
summarize("https://edwarddonner.com")

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://edwarddonner.com")

# %% [markdown]
# ## Test on additional web pages + OLLAMA

# %%
import os
from openai import OpenAI

OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
ollama.models.list()
# Out:
# SyncPage[Model](data=[Model(id='gemma3:latest', created=1774545959, object='model', owned_by='library')], object='list')

# %%
# Step 1: Create your prompts

system_prompt = "could you take this wish and create a plan of 3 steps to achieve it. Create maximum 4 lines."
user_prompt = """
    Hi, I really wish to get to palantir. How can I do that?
"""

# Step 2: Make the messages list
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
]

# Step 3: Call OpenAI
response = ollama.chat.completions.create(
    model="gemma3",
    messages=messages
)
# Step 4: print the result
print(response.choices[0].message.content)
# Out:
# Okay, here’s a 3-step plan to increase your chances of working at Palantir:
#
# 1. **Skill Up:** Focus on data analytics, data engineering, or software development – Palantir heavily utilizes these. Take relevant courses and build a strong portfolio.
# 2. **Network Strategically:** Attend industry events (particularly those focused on data and security) and connect with Palantir employees on LinkedIn.
# 3. **Tailor Your Application:**  Thoroughly research Palantir’s mission and specific needs, highlighting how your skills align with their projects.
