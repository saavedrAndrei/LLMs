# %%
import os 
import tiktoken

# %%
encoding = tiktoken.encoding_for_model("gpt-4.1-mini")

tokens = encoding.encode("Hi my name is Andrei")

# %%
tokens
# Out:
# [12194, 922, 1308, 382, 1958, 13409]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 12194 = Hi
# 922 =  my
# 1308 =  name
# 382 =  is
# 1958 =  And
# 13409 = rei

# %%
encoding.decode([1958])
# Out:
# ' And'

# %% [markdown]
# ## The Illusion of "Memory"

# %% [markdown]
# - We pass the LLM the entire conversation so far in the input prompt every time.

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Ed!"},
    {"role": "assistant", "content": "Hi Ed! How can I assist you today?"},
    {"role": "user", "content": "What's my name?"}
    ]
